# %%
import pandas as pd

df = pd.read_csv("data/weather_forecasts_raw.csv", parse_dates=["TimeDK"])

# %%
df
# Out:
#                     TimeDK    region   Latitude  Longitude  Elevation  \
# 0      2022-01-01 00:00:00  DK1_west  56.100006   8.500000       27.0
# 1      2022-01-01 01:00:00  DK1_west  56.100006   8.500000       27.0
# 2      2022-01-01 02:00:00  DK1_west  56.100006   8.500000       27.0
# 3      2022-01-01 03:00:00  DK1_west  56.100006   8.500000       27.0
# 4      2022-01-01 04:00:00  DK1_west  56.100006   8.500000       27.0
# ...                    ...       ...        ...        ...        ...
# 184315 2026-03-16 19:00:00  DE_north  54.300003   9.699997       16.0
# 184316 2026-03-16 20:00:00  DE_north  54.300003   9.699997       16.0
# 184317 2026-03-16 21:00:00  DE_north  54.300003   9.699997       16.0
# 184318 2026-03-16 22:00:00  DE_north  54.300003   9.699997       16.0
# 184319 2026-03-16 23:00:00  DE_north  54.300003   9.699997       16.0
#
#                  Timezone TimezoneAbbreviation  wind_speed_100m  \
# ...
