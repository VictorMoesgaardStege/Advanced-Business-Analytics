# %%
import pandas as pd

df = pd.read_csv("data/weather_error_distributions.csv")

# %%
df
# Out:
#       forecast_variable      actual_variable  horizon_hours      n  \
# 0           cloud_cover          cloud_cover             24  16320
# 1           cloud_cover          cloud_cover             48  16320
# 2           cloud_cover          cloud_cover             72  16320
# 3           cloud_cover          cloud_cover             96  16320
# 4           cloud_cover          cloud_cover            120  16320
# 5          pressure_msl         pressure_msl             24  16320
# 6          pressure_msl         pressure_msl             48  16320
# 7          pressure_msl         pressure_msl             72  16320
# 8          pressure_msl         pressure_msl             96  16320
# 9          pressure_msl         pressure_msl            120  16320
# 10  shortwave_radiation  shortwave_radiation             24  16320
# 11  shortwave_radiation  shortwave_radiation             48  16320
# 12  shortwave_radiation  shortwave_radiation             72  16320
# ...
